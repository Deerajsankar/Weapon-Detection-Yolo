# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 37.4 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.1 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ...

# %%
import torch
import ultralytics
from ultralytics import YOLO
import roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="h10EWF7ZZMudosSAyhzm")
project = rf.workspace("msdeeraj").project("weapon-detection-xzpsf")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Weapon-Detection-2 in yolov11:: 100%|██████████| 1834/1834 [00:00<00:00, 7903.87it/s]

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO(r"/content/yolo11n.pt")  

# Train the model
results = model.train(
    data="/kaggle/working/Weapon-Detection-2/data.yaml",  
    epochs=50,  
    batch=16,   
    imgsz=911  
)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 181MB/s]
# Ultralytics 8.3.93 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the best model weights
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

# Evaluate the model on the validation dataset
metrics = model.val()  # This will use the validation dataset specified in data.yaml
print(metrics.box.map)  # mAP50-95
print(metrics.box.map50)  # mAP50
print(metrics.box.map75)  # mAP75
# Out:
# Ultralytics 8.3.93 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /kaggle/working/Weapon-Detection-2/valid/labels.cache... 149 images, 5 backgrounds, 0 corrupt: 100%|██████████| 149/149 [00:00<?, ?it/s]
# val: WARNING ⚠️ /kaggle/working/Weapon-Detection-2/valid/images/knife_12_16_png_jpg.rf.b7342137d5eacc630d31d654c7e70cab.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/Weapon-Detection-2/valid/images/knife_12_23_png_jpg.rf.84a1f7aea418a256e1f065a162bae38e.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/Weapon-Detection-2/valid/images/knife_12_30_png_jpg.rf.1790f6d922fbe9658d25ab9d3f7d33d8.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/Weapon-Detection-2/valid/images/knife_12_6_png_jpg.rf.3768d356659d9bd84b9db1cc864a00d3.jpg: 1 duplicate labels removed
# ...
